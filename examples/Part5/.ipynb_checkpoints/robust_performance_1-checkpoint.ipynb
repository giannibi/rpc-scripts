# %% [markdown]
# Solution of the robust performance problem via $\mu$-synthesis![rp2.jpg](attachment:fa2df0a2-9eea-417a-9e3d-2e12ef861053.jpg)

# %%
import matplotlib.pyplot as plt
from itertools import product
import slycot as sly
import numpy as np
import control as ct
import rpc_diism.robust as rb

# %%
# Plant P
den = [0.2, 1.2, 1]
P = ct.tf([[[1], [1]],
              [[2, 1], [2]]],
             [[den, den],
              [den, den]])
display("Plant transfer function", P)
# Out:
# 'Plant transfer function'
# TransferFunction(
# [[array([1]), array([1])],
#  [array([2, 1]), array([2])]],
# [[array([0.2, 1.2, 1. ]), array([0.2, 1.2, 1. ])],
#  [array([0.2, 1.2, 1. ]), array([0.2, 1.2, 1. ])]],
# outputs=2, inputs=2)

# %% [markdown]
# Define performance weight and uncertainty weight

# %%
# Uncertainty block weight Wi
Mi = 20
ei = 1e-4
wbi = 15 # Crossover frequency
Wi_1 = ct.ss(rb.weightU(wbi, Mi, ei, 1))
Wi = Wi_1.append(Wi_1) 

# Performance weight We (weight on S)
M = 20
e = 1e-4
wb = 0.25 # Crossover frequency
We_1 = ct.ss(rb.weightS(wb, M, e, 1))
We = We_1.append(We_1)

# %% [markdown]
# Construct the LFT

# %%
Wi.input_labels = ['u[0]', 'u[1]']
Wi.output_labels = ['zdelta[0]', 'zdelta[1]']
We.input_labels = ['y[0]', 'y[1]']
We.output_labels = ['z[0]', 'z[1]']
P.input_labels = ['u[0]','u[1]']
P.output_labels = ['yp[0]','yp[1]']

# Summing junction to ybar (additive uncertainty)
sumdelta = ct.summing_junction(inputs=['yp','wdelta'], output='ybar', dimension=2)

# Feedback: y = r-ybar
fbk = ct.summing_junction(inputs=['r','-ybar'], output='y', dimension=2)

# Generate the G transfer function of the LFT
G = ct.minreal(ct.interconnect([P, Wi, We, sumdelta, fbk],
                    inputs=['wdelta[0]','wdelta[1]','r[0]','r[1]','u[0]','u[1]'],
                    outputs=['zdelta[0]','zdelta[1]','z[0]','z[1]','y[0]','y[1]']), 
                    verbose=False)

# %% [markdown]
# Do $\mu$-synthesis.

# %%
# Controller I/O sizes
f = 2

# Extended uncertainty structure: a 2x2 uncertainty block and a 2x2 performance block
nblock = np.array([2,2])
# This has to be == 2 (complex uncertainty) for each block (other values are not implemented)
itype = np.array([2,2])

# Frequency range for mu computations
omega = np.logspace(-3, 3, 101)

# Do mu-synthesis via D-K iteration
K, best_nubar, init_mubar, best_mubar, gamma = rb.musyn(G, f, nblock, itype, omega)

display("Best upper bound (nubar) to mu norm of Tzw_delta: ", best_nubar)
# Out:
# Infinity norm of Tzw_delta with initial Hinfinity controller:  1.15853448079406
# Iteration # 1
# Best upper bound to mu norm of Tzw_delta:  1.1583914905967414
# Iteration # 2
# Best upper bound to mu norm of Tzw_delta:  0.9813817871692981
# Iteration # 3
# No better upper bound to mu norm of Tzw_delta found: trying D order  4 qutol  2
# Iteration # 4
# No better upper bound to mu norm of Tzw_delta found: trying D order  4 qutol  3
# Iteration # 5
# No better upper bound to mu norm of Tzw_delta found: trying D order  4 qutol  4
# Iteration # 6
# No better upper bound to mu norm of Tzw_delta found: trying D order  5 qutol  1
# Iteration # 7
# No better upper bound to mu norm of Tzw_delta found: trying D order  5 qutol  2
# Iteration # 8
# No better upper bound to mu norm of Tzw_delta found: trying D order  5 qutol  3
# Iteration # 9
# No better upper bound to mu norm of Tzw_delta found: trying D order  5 qutol  4
# Iteration # 10
# No better upper bound to mu norm of Tzw_delta found: trying D order  6 qutol  1
# 'Best upper bound (nubar) to mu norm of Tzw_delta: '
# 0.9813817871692981

# %%
plt.loglog(omega, best_mubar, label=r'Final $\bar \mu$')
plt.loglog(omega, init_mubar, label=r'Initial $\bar \mu$')
plt.ylabel(r'$\bar\mu$ value')
plt.xlabel('freq [rad/s]')
plt.legend()
plt.title(r'Initial and final $\bar\mu$')
# Out:
# Text(0.5, 1.0, 'Initial and final $\\bar\\mu$')

# %% [markdown]
# Verify performance on the nominal system. It must hold that $\|W_e S\|_\infty \leq \bar\nu$ for $\bar\nu=\sup_\omega \bar\mu$ corresponding to the optimal controller.

# %%
# Compute sensitivity for the nominal system
I = ct.ss([], [], [], np.eye(2)) # Identity system  
Delta = 0 * I
Delta.input_labels = ['zdelta[0]','zdelta[1]']
Delta.output_labels = ['wdelta[0]','wdelta[1]']               
K.input_labels = ['y[0]','y[1]']
K.output_labels = ['u[0]','u[1]'] 

S = ct.minreal(ct.interconnect([P, Delta, K, Wi, We, sumdelta, fbk],
                    inputs=['r[0]','r[1]'],
                    outputs=['y[0]','y[1]'], check_unused=False), verbose=False)

# Compute singular values of S over frequency
Ssv = rb.sigma(S, omega)

# We plot the singular values of gamma*invss(We) along with S
# for gamma = best_mu_upper_bound
Weinv = rb.invss(We)
Weinvsv = rb.sigma(Weinv, omega) * best_nubar

plt.semilogx(omega, 20*np.log10(Ssv[:, 0]), 'm', label=r'$\sigma_1(S)$')
plt.semilogx(omega, 20*np.log10(Ssv[:, 1]), 'g', label=r'$\sigma_2(S)$')
plt.semilogx(omega, 20*np.log10(Weinvsv[:, 0]), 'm:', label=r'$\bar\nu \sigma_1({We_1}^{-1})$')
plt.semilogx(omega, 20*np.log10(Weinvsv[:, 1]), 'g:', label=r'$\bar\nu \sigma_2({We_1}^{-1})$')
plt.ylim([-60, 30])
plt.ylabel('magnitude [dB]')
plt.xlim([1e-3, 1e3])
plt.xlabel('freq [rad/s]')
plt.legend()
plt.title('Singular values of S vs. nubar*inv(We) for the nominal system')
# Out:
# Text(0.5, 1.0, 'Singular values of S vs. nubar*inv(We) for the nominal system')

# %% [markdown]
# Verify the performance under a "random" perturbation satisfying the bound $\|\Delta\|_\infty = 1/ \bar\nu$ for $\bar\nu=\sup_\omega \bar\mu$. It must hold that $\|W_e S\|_\infty \leq\bar\nu$.

# %%
# Generate a perturbation with norm equal to 1/best_nubar
Delta = - 1/best_nubar * I
Delta.input_labels = ['zdelta[0]','zdelta[1]']
Delta.output_labels = ['wdelta[0]','wdelta[1]'] 

# Sensitivity under perturbation
S = ct.minreal(ct.interconnect([P, Delta, K, Wi, We, sumdelta, fbk],
                    inputs=['r[0]','r[1]'],
                    outputs=['y[0]','y[1]'], check_unused=False), verbose=False)

# Compute singular values of S over frequency
Ssv = rb.sigma(S, omega)

# We plot the singular values of gamma*invss(We) along with S
Weinv = rb.invss(We)
Weinvsv = rb.sigma(Weinv, omega) * best_nubar

plt.semilogx(omega, 20*np.log10(Ssv[:, 0]), 'm', label=r'$\sigma_1(S)$')
plt.semilogx(omega, 20*np.log10(Ssv[:, 1]), 'g', label=r'$\sigma_2(S)$')
plt.semilogx(omega, 20*np.log10(Weinvsv[:, 0]), 'm:', label=r'$\bar\nu \sigma_1({We_1}^{-1})$')
plt.semilogx(omega, 20*np.log10(Weinvsv[:, 1]), 'g:', label=r'$\bar\nu \sigma_2({We_1}^{-1})$')
plt.ylim([-60, 30])
plt.ylabel('magnitude [dB]')
plt.xlim([1e-3, 1e3])
plt.xlabel('freq [rad/s]')
plt.legend()
plt.title('Singular values of S vs. nubar*inv(We) for perturbed system')
# Out:
# Text(0.5, 1.0, 'Singular values of S vs. nubar*inv(We) for perturbed system')

# %% [markdown]
# Apparently, we hit a very particular case! In fact, we have that $\|W_e S\|_\infty=\bar\nu$. This means two things: 1) The upper bound $\bar\nu$ is the "real" $\mu$ here, i.e., there is no gap between the two; 2) The $\Delta$ that we have chosen is almost the "worst" possible perturbation in the admissible set, because it causes the closed loop to sit on the boundary of the performance specification!
